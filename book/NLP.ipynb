# %% [markdown]
# <a href="https://colab.research.google.com/github/yujiimt/NLP/blob/master/book/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = """
こんにちは。
ファイルの読み込み練習中
awesome !
"""


with open('example.txt', "w") as f:
  f.write(a)

# %%
  import requests

# %%
url = 'https://api.gnavi.co.jp/PhotoSearchAPI/v3/'
params = {'keyid':'####', 'menu_name':'ラーメン'}
response = requests.get(url, params = params)
response.json()
# Out:
# {'response': {'0': {'photo': {'areaname_l': '町田・多摩',
#     'areaname_m': '町田',
#     'areaname_s': '町田',
#     'category': 'ラーメン',
#     'comment': '超こってりラーメンががうまい。なんか特許があるらしい。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/e6/41/79812_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/e6/41/79812_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/e6/41/79812_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/e6/41/79812.jpeg'},
#     'latitude': '35.543834',
#     'longitude': '139.447537',
#     'menu_finish_flag': 0,
#     'menu_id': 78256,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ＦＲＢ',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '7377127',
#     'shop_name': '一蘭町田店',
#     'shop_url': 'https://r.gnavi.co.jp/34n4jgkb0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 1,
#     'update_date': '2010-11-03T16:08:20+09:00',
#     'vote_id': '79812'}},
#   '1': {'photo': {'areaname_l': '銀座・有楽町・築地',
#     'areaname_m': '銀座',
#     'areaname_s': '銀座（三越・松屋方面）',
#     'category': 'ラーメン',
#     'comment': 'スープが絶妙。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/0a/1e/80084_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/0a/1e/80084_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/0a/1e/80084_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/0a/1e/80084.jpeg'},
#     'latitude': '',
#     'longitude': '',
#     'menu_finish_flag': 0,
#     'menu_id': 78444,
#     'menu_name': '長浜ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'さとうさとうさとう',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '7210323',
#     'shop_name': 'やまちゃん 銀座店',
#     'shop_url': 'https://r.gnavi.co.jp/47wpewwc0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-11-12T15:35:51+09:00',
#     'vote_id': '80084'}},
#   '10': {'photo': {'areaname_l': '戸塚・東戸塚',
#     'areaname_m': '戸塚・東戸塚',
#     'areaname_s': '戸塚・東戸塚',
#     'category': 'ラーメン',
#     'comment': '横浜家系ラーメン。めちゃめちゃこってりなんだけど、無性に食べたくなっちゃうんだよなぁ・・・。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/d0/27/87925_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/d0/27/87925_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/d0/27/87925_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/d0/27/87925.jpeg'},
#     'latitude': '35.428238',
#     'longitude': '139.557364',
#     'menu_finish_flag': 0,
#     'menu_id': 84867,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'hirromi',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF14:神奈川県',
#     'shop_id': '5500067',
#     'shop_name': '壱八家 東戸塚本店',
#     'shop_url': 'https://r.gnavi.co.jp/6hrs5jpz0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-21T10:30:57+09:00',
#     'vote_id': '87925'}},
#   '11': {'photo': {'areaname_l': '本厚木・海老名',
#     'areaname_m': '本厚木・厚木',
#     'areaname_s': '本厚木・厚木',
#     'category': 'ラーメン',
#     'comment': 'インパクトの強い豚骨醤油のスープはハマります！',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88515_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88515_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88515_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88515.jpeg'},
#     'latitude': '35.462226',
#     'longitude': '139.357107',
#     'menu_finish_flag': 0,
#     'menu_id': 82941,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'so-pink',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF14:神奈川県',
#     'shop_id': '5500887',
#     'shop_name': '梅家 舎弟',
#     'shop_url': 'https://r.gnavi.co.jp/9c7tjrmv0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-22T00:37:52+09:00',
#     'vote_id': '88515'}},
#   '12': {'photo': {'areaname_l': '錦糸町・押上・新小岩',
#     'areaname_m': '錦糸町・住吉',
#     'areaname_s': '錦糸町',
#     'category': 'ラーメン',
#     'comment': '大蒜が効いています。麺が太くて食べ応えがあります。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/25/f1/88609_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/25/f1/88609_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/25/f1/88609_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/25/f1/88609.jpeg'},
#     'latitude': '35.695679',
#     'longitude': '139.812320',
#     'menu_finish_flag': 0,
#     'menu_id': 85397,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '5497323',
#     'shop_name': 'ラーメンヨシベー 錦糸町店',
#     'shop_url': 'https://r.gnavi.co.jp/3wfy4xyr0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-22T08:48:26+09:00',
#     'vote_id': '88609'}},
#   '13': {'photo': {'areaname_l': '旭川・富良野・名寄',
#     'areaname_m': '旭川',
#     'areaname_s': '旭川',
#     'category': 'ラーメン',
#     'comment': '表面の焦がしラードが特徴。こってりと美味しい。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/72/53/88219_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/72/53/88219_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/72/53/88219_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/72/53/88219.jpeg'},
#     'latitude': '43.764558',
#     'longitude': '142.372219',
#     'menu_finish_flag': 0,
#     'menu_id': 85112,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF01:北海道',
#     'shop_id': '7210322',
#     'shop_name': '蜂屋ラーメン 本店',
#     'shop_url': 'https://r.gnavi.co.jp/2td4zayn0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-22T10:13:05+09:00',
#     'vote_id': '88219'}},
#   '14': {'photo': {'areaname_l': '本厚木・海老名',
#     'areaname_m': '本厚木・厚木',
#     'areaname_s': '本厚木・厚木',
#     'category': 'ラーメン',
#     'comment': '香りがいい！インパクトのある豚骨醤油です！',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88659_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88659_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88659_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/88659.jpeg'},
#     'latitude': '35.462226',
#     'longitude': '139.357107',
#     'menu_finish_flag': 0,
#     'menu_id': 82949,
#     'menu_name': 'ネギラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'P_ein_kumi',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF14:神奈川県',
#     'shop_id': '5500887',
#     'shop_name': '梅家 舎弟',
#     'shop_url': 'https://r.gnavi.co.jp/9c7tjrmv0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-22T10:59:36+09:00',
#     'vote_id': '88659'}},
#   '2': {'photo': {'areaname_l': '錦糸町・押上・新小岩',
#     'areaname_m': '亀戸',
#     'areaname_s': '亀戸',
#     'category': 'ラーメン',
#     'comment': 'もやし多目でヘルシーです。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/b7/76/80098_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/b7/76/80098_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/b7/76/80098_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/b7/76/80098.jpeg'},
#     'latitude': '35.697077',
#     'longitude': '139.842890',
#     'menu_finish_flag': 0,
#     'menu_id': 78459,
#     'menu_name': 'とんこつラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '5497391',
#     'shop_name': 'めん屋 亀久',
#     'shop_url': 'https://r.gnavi.co.jp/ge0nx9470000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-11-14T19:06:54+09:00',
#     'vote_id': '80098'}},
#   '3': {'photo': {'areaname_l': '上野・浅草・日暮里',
#     'areaname_m': '上野',
#     'areaname_s': '上野',
#     'category': 'ラーメン',
#     'comment': 'ラーメン（赤）。麺が太くて、それだけでお腹が満たされてしまいますが、若い人には良いのかもしれません。スープも凝っていてとても美味しいです。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/80657_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/80657_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/80657_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/80657.jpeg'},
#     'latitude': '35.709010',
#     'longitude': '139.775934',
#     'menu_finish_flag': 0,
#     'menu_id': 3826,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '6346573',
#     'shop_name': '麺屋武蔵 武骨 御徒町店',
#     'shop_url': 'https://r.gnavi.co.jp/j5h3431w0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-11-22T22:19:52+09:00',
#     'vote_id': '80657'}},
#   '4': {'photo': {'areaname_l': '品川・五反田・大崎',
#     'areaname_m': '品川',
#     'areaname_s': '品川（アトレ品川・インターシティ方面）',
#     'category': 'ラーメン',
#     'comment': 'さっぱりしていそうに見えるけれど、そうでもなく、油がこってりして食べ応えがあります。生たまねぎをいれることで脂分が気にならなくなります。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/29/c6/80997_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/29/c6/80997_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/29/c6/80997_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/29/c6/80997.jpeg'},
#     'latitude': '35.626771',
#     'longitude': '139.738007',
#     'menu_finish_flag': 0,
#     'menu_id': 79237,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'amatouha',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '5496790',
#     'shop_name': 'せたが屋 品川店',
#     'shop_url': 'https://r.gnavi.co.jp/g2wpd5a90000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-11-27T22:45:12+09:00',
#     'vote_id': '80997'}},
#   '5': {'photo': {'areaname_l': '上野・浅草・日暮里',
#     'areaname_m': '上野',
#     'areaname_s': '上野',
#     'category': 'ラーメン',
#     'comment': '麺がとても太くて、満腹になります。食べ応えがありました。おいしい！',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/81001_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/81001_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/81001_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/87/12/81001.jpeg'},
#     'latitude': '35.709010',
#     'longitude': '139.775934',
#     'menu_finish_flag': 0,
#     'menu_id': 79241,
#     'menu_name': '黒\u3000ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'amatouha',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '6346573',
#     'shop_name': '麺屋武蔵 武骨 御徒町店',
#     'shop_url': 'https://r.gnavi.co.jp/j5h3431w0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-11-27T23:03:18+09:00',
#     'vote_id': '81001'}},
#   '6': {'photo': {'areaname_l': '本厚木・海老名',
#     'areaname_m': '本厚木・厚木',
#     'areaname_s': '本厚木・厚木',
#     'category': 'ラーメン',
#     'comment': '豚骨の香りが強い家系ラーメン。ネギは風邪にも効きます★',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/85464_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/85464_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/85464_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/cc/a3/85464.jpeg'},
#     'latitude': '35.462226',
#     'longitude': '139.357107',
#     'menu_finish_flag': 0,
#     'menu_id': 82949,
#     'menu_name': 'ネギラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF14:神奈川県',
#     'shop_id': '5500887',
#     'shop_name': '梅家 舎弟',
#     'shop_url': 'https://r.gnavi.co.jp/9c7tjrmv0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-18T13:04:10+09:00',
#     'vote_id': '85464'}},
#   '7': {'photo': {'areaname_l': '大和・中央林間・二俣川',
#     'areaname_m': '中央林間・鶴間',
#     'areaname_s': '中央林間・鶴間',
#     'category': 'ラーメン',
#     'comment': 'こってりまろやかな豚骨醤油スープは寒い季節におすすめ★',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/43/d8/85474_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/43/d8/85474_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/43/d8/85474_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/43/d8/85474.jpeg'},
#     'latitude': '35.510321',
#     'longitude': '139.460774',
#     'menu_finish_flag': 0,
#     'menu_id': 82955,
#     'menu_name': 'のりたまラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF14:神奈川県',
#     'shop_id': '6545158',
#     'shop_name': 'ラーメン大桜',
#     'shop_url': 'https://r.gnavi.co.jp/847rvyyv0000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-18T13:22:33+09:00',
#     'vote_id': '85474'}},
#   '8': {'photo': {'areaname_l': 'みなとみらい・関内・中華街',
#     'areaname_m': '桜木町',
#     'areaname_s': '桜木町',
#     'category': 'ラーメン',
#     'comment': '替え玉するのが当たり前^^;',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/5d/3f/87133_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/5d/3f/87133_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/5d/3f/87133_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/5d/3f/87133.jpeg'},
#     'latitude': '35.449482',
#     'longitude': '139.630573',
#     'menu_finish_flag': 0,
#     'menu_id': 14237,
#     'menu_name': 'ラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': '杏樹☆',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF14:神奈川県',
#     'shop_id': '7377098',
#     'shop_name': '一蘭横浜桜木町店',
#     'shop_url': 'https://r.gnavi.co.jp/cvfwxfn00000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-19T23:37:21+09:00',
#     'vote_id': '87133'}},
#   '9': {'photo': {'areaname_l': '錦糸町・押上・新小岩',
#     'areaname_m': '錦糸町・住吉',
#     'areaname_s': '錦糸町',
#     'category': 'ラーメン店',
#     'comment': '見た目よりあっさりとしていて食べやすいです。',
#     'image_url': {'url_1024': 'https://mr.gnavi.co.jp/cont/menu_image/c2/68/87202_l.jpeg',
#      'url_200': 'https://mr.gnavi.co.jp/cont/menu_image/c2/68/87202_s.jpeg',
#      'url_250': 'https://mr.gnavi.co.jp/cont/menu_image/c2/68/87202_m.jpeg',
#      'url_320': 'https://mr.gnavi.co.jp/cont/menu_image/c2/68/87202.jpeg'},
#     'latitude': '35.695661',
#     'longitude': '139.812392',
#     'menu_finish_flag': 0,
#     'menu_id': 55416,
#     'menu_name': 'ハッスルラーメン',
#     'messages': {'first_shop_message': {'message_body': '', 'send_date': ''},
#      'shop_message_count': 0,
#      'user_message_count': 0},
#     'nickname': 'ぐるなび会員',
#     'photo_genre_id': '1',
#     'photo_genre_name': '料理・ドリンク',
#     'photo_scene_id': '',
#     'photo_scene_name': '',
#     'prefname': 'PREF13:東京都',
#     'shop_id': '5838196',
#     'shop_name': 'ハッスルラーメンホンマ 錦糸町店',
#     'shop_url': 'https://r.gnavi.co.jp/mp84mnx40000/?ak=2HDfQXu1mm3Q%2FP0tt1uuEsQmalvSLTrRvuHq79v5xKc%3D',
#     'total_score': '3.0',
#     'umaso_count': 0,
#     'update_date': '2010-12-20T09:00:26+09:00',
#     'vote_id': '87202'}},
#   '@attributes': {'api_version': 'v3'},
#   'hit_per_page': 15,
#   'total_hit_count': 5019}}

# %%
 import json
 import requests

def fetch_data(**params):
  url = "https://api.gnavi.co.jp/PhotoSearchAPI/v3/"
  response = requests.get(url, params = params)
  return response.json()


def extract_data(response):
  for key in response["response"].keys():
    if not key.isdigit():
      continue
    d = response['response'][key]['photo']
    if d.get('comment') and d.get('total_score'):
      comment = d['comment']
      score = d['total_score']
      data = {
          'comment': comment,
          'score' : score
      }
      yield data

def save_as_json(save_file, record):
  with open(save_file, mode = 'a') as f:
    f.write(json.dumps(record) + '\n')

def main():
  #定数の設定
  raw_data = 'data/raw_data.json'
  save_file = 'data/dataset.json1'
  keyid = '####'


  # データの取得と保存
  response = fetch_data(
    keyid = keyid,
    area = '新宿',
    hit_per_page = 50,
    offset_page = 1  
  )

  save_as_json(raw_data, response)


  #必要な情報の抽出と保存

  records = extract_data(response)
  for record in records:
    save_as_json(save_file, record)

if __name__  == '__main__':
  main()

# %%
main()

# %%
fetch_data()
# Out:
# {'gnavi': {'@attribute': {'api_version': 'v3'},
#   'error': [{'code': 401, 'message': 'keyidを指定してください'}]}}
